# %%
# Student data
students = [
    {
        "nim": 2046363636,
        "nama": "Iwan",
        "semester": 6,
        "hasil": [
            {
                "mata_kuliah": "kecerdasan buatan",
                "hadir": 18,
                "sks": 3,
                "nilai": {
                    "tugas": 75,
                    "uts": 80,
                    "uas": 77
                }
            },
            {
                "mata_kuliah": "basis data 1",
                "hadir": 20,
                "sks": 3,
                "nilai": {
                    "tugas": 80,
                    "uts": 82,
                    "uas": 67
                }
            },
            {
                "mata_kuliah": "digital enterpreneur",
                "hadir": 14,
                "sks": 2,
                "nilai": {
                    "tugas": 90,
                    "uts": 82,
                    "uas": 80
                }
            }
        ]
    },
    {
        "nim": 2046363777,
        "nama": "Saepulloh",
        "semester": 2,
        "hasil": [
            {
                "mata_kuliah": "algoritma & pemrogaman 1",
                "hadir": 20,
                "sks": 3,
                "nilai": {
                    "tugas": 90,
                    "uts": 80,
                    "uas": 70
                }
            },
            {
                "mata_kuliah": "kalkulus 1",
                "hadir": 21,
                "sks": 3,
                "nilai": {
                    "tugas": 70,
                    "uts": 60,
                    "uas": 67
                }
            },
            {
                "mata_kuliah": "statistika dan probabilitas",
                "hadir": 13,
                "sks": 2,
                "nilai": {
                    "tugas": 90,
                    "uts": 70,
                    "uas": 88
                }
            }
        ]
    },
    {
        "nim": 2046363790,
        "nama": "Sholihin",
        "semester": 8,
        "hasil": [
            {
                "mata_kuliah": "Sistem Penunjang Keputusan",
                "hadir": 19,
                "sks": 3,
                "nilai": {
                    "tugas": 80,
                    "uts": 90,
                    "uas": 65
                }
            },
            {
                "mata_kuliah": "Rekayasa Perangkat Lunak",
                "hadir": 21,
                "sks": 3,
                "nilai": {
                    "tugas": 70,
                    "uts": 80,
                    "uas": 77
                }
            },
            {
                "mata_kuliah": "Etika Profesi",
                "hadir": 14,
                "sks": 2,
                "nilai": {
                    "tugas": 90,
                    "uts": 80,
                    "uas": 88
                }
            }
        ]
    }
]
# Function to calculate score
bobot = {
    "hadir": 10,
    "tugas": 20,
    "uts": 30,
    "uas": 40
}

def hitung_nilai(sks, hadir, tugas, uts, uas, bobot=bobot):
    max_hadir = 0
    # Determine maximum attendance based on SKS
    if sks == 2:
        max_hadir = 14
    elif sks == 3:
        max_hadir = 21
    else:
        return "SKS tidak valid"
    
    # Calculate weighted scores
    # Attendance
    hadir_score = (hadir / max_hadir) * bobot["hadir"]
    
    # Tugas, UTS, UAS
    tugas_score = (tugas / 100) * bobot["tugas"]
    uts_score = (uts / 100) * bobot["uts"]
    uas_score = (uas / 100) * bobot["uas"]
    
    # Total score
    total_score = hadir_score + tugas_score + uts_score + uas_score
    
    return round(total_score, 2)
# Function to determine letter grade based on numerical score
def get_grade(nilai):
    if nilai >= 85:
        return "A"
    elif nilai >= 70:
        return "B"
    elif nilai >= 55:
        return "C"
    elif nilai >= 40:
        return "D"
    else:
        return "E"
# Creating the results list
results = []

# Iterate over each student
for student in students:
    student_summary = {
        "nim": student["nim"],
        "nama": student["nama"],
        "rangkuman_nilai": []
    }
    
    # Iterate over each subject for the student
    for mk in student["hasil"]:
        # Calculate the final score using the hitung_nilai function
        final_score = hitung_nilai(mk["sks"], mk["hadir"], mk["nilai"]["tugas"], mk["nilai"]["uts"], mk["nilai"]["uas"])
        
        # Check if the final score is valid
        if isinstance(final_score, (int, float)):  # Check if it's a number
            # Create a summary for the course
            course_summary = {
                "mata_kuliah": mk["mata_kuliah"],
                "nilai": f"{final_score} : 0 - 100",
                "Grade": f": {get_grade(final_score)}"
            }
            
            # Add the course summary to the student's summary
            student_summary["rangkuman_nilai"].append(course_summary)
        else:
            # Handle the invalid score case
            course_summary = {
                "mata_kuliah": mk["mata_kuliah"],
                "nilai": "Invalid score",
                "Grade": "N/A"
            }
            student_summary["rangkuman_nilai"].append(course_summary)
    
    # Add the student summary to the results
    results.append(student_summary)

# Print the results
import pprint
pprint.pprint(results)

import pprint
from matplotlib import pyplot as plt

# Your code here
pprint.pprint(results)

# Plotting code
x = [10, 30, 50]
plt.plot(x)
plt.show()

from matplotlib import pyplot as plt

x = [10, 30, 50]
y0 = [20, 30, 40]
y = [25, 15, 30]

plt.plot(x, y, color="green", label="Line 1")
plt.plot(x, y0, label="Line 2")

plt.title("Contoh plot")
plt.xlabel("nilai x")
plt.ylabel("nilai y")
plt.legend()  # Add a legend to differentiate the lines
plt.show()

data_rekap = [
    {
        "tahun": 1995,
        "penjualan": 300,
        "operasional": 150,
        "pajak": 50,
        "pendapatan_lain": 135
    },
    {
        "tahun": 1997,
        "penjualan": 320,
        "operasional": 120,
        "pajak": 70,
        "pendapatan_lain": 105
    },
    {
        "tahun": 1991,
        "penjualan": 200,
        "operasional": 75,
        "pajak": 35,
        "pendapatan_lain": 85
    },
    {
        "tahun": 1992,
        "penjualan": 320,
        "operasional": 170,
        "pajak": 80,
        "pendapatan_lain": 235
    },
    {
        "tahun": 2001,
        "penjualan": 300,
        "operasional": 150,
        "pajak": 50,
        "pendapatan_lain": 135
    },
    {
        "tahun": 2003,
        "penjualan": 500,
        "operasional": 350,
        "pajak": 100,
        "pendapatan_lain": 55
    },
    {
        "tahun": 2005,
        "penjualan": 750,
        "operasional": 450,
        "pajak": 200,
        "pendapatan_lain": 155
    }
]
# expected data
data_graph = {
    "tahun": [...], # x
    "penjualan": [...] # y
}
# mapping
# data_map = { <tahun>: <penjualan>}
data_map = { data["tahun"]: data["penjualan"] for data in data_rekap}
data_map
{1995: 300, 1997: 320, 1991: 200, 1992: 320, 2001: 300, 2003: 500, 2005: 750}
# Sorting data tahun
tahun = list(data_map.keys())
tahun.sort()
tahun
[1991, 1992, 1995, 1997, 2001, 2003, 2005]
# get data penjualan
penjualan = [data_map[_tahun]for _tahun in tahun]
penjualan
[200, 320, 300, 320, 300, 500, 750]
data_graph = {
    "tahun": tahun,
    "penjualan": penjualan,
    "pajak": [20, 30, 30, 20, 30, 50, 75]
}
data_graph
{'tahun': [1991, 1992, 1995, 1997, 2001, 2003, 2005],
 'penjualan': [200, 320, 300, 320, 300, 500, 750],
 'pajak': [20, 30, 30, 20, 30, 50, 75]}
plt.plot(data_graph["tahun"], data_graph["penjualan"],"o-", label="penjualan")
plt.plot(data_graph["tahun"], data_graph["pajak"],"o-", label="pajak")

plt.title("Data rekapitulasi Tahunan")
plt.legend(loc="upper left")
plt.xlabel("Tahun")
plt.ylabel("Dalam jutaan Rp.")
plt.show()

# Data dari soal
data_rekap = [
    {"tahun": 1995, "penjualan": 300, "operasional": 150, "pajak": 50, "pendapatan_lain": 135},
    {"tahun": 1997, "penjualan": 320, "operasional": 120, "pajak": 70, "pendapatan_lain": 105},
    {"tahun": 1991, "penjualan": 200, "operasional": 75, "pajak": 35, "pendapatan_lain": 85},
    {"tahun": 1992, "penjualan": 320, "operasional": 170, "pajak": 80, "pendapatan_lain": 235},
    {"tahun": 2001, "penjualan": 300, "operasional": 150, "pajak": 50, "pendapatan_lain": 135},
    {"tahun": 2003, "penjualan": 500, "operasional": 350, "pajak": 100, "pendapatan_lain": 55},
    {"tahun": 2005, "penjualan": 750, "operasional": 450, "pajak": 200, "pendapatan_lain": 155}
]
# Memisahkan data ke dalam struktur yang diharapkan
data_graph = {
    "tahun": [d["tahun"] for d in data_rekap],
    "penjualan": [d["penjualan"] for d in data_rekap],
    "pajak": [d["pajak"] for d in data_rekap],
    "operasional": [d["operasional"] for d in data_rekap],
    "pendapatan_lain": [d["pendapatan_lain"] for d in data_rekap],
    "laba": [d["penjualan"] + d["pendapatan_lain"] - d["pajak"] - d["operasional"] for d in data_rekap]
}
# Plot data
plt.plot(data_graph["tahun"], data_graph["laba"], color="blue", marker="o", label="Laba")
plt.plot(data_graph["tahun"], data_graph["penjualan"], color="green", marker="o", label="Penjualan")
plt.title("Grafik Laba dan Penjualan")
plt.xlabel("Tahun")
plt.ylabel("Nilai (dalam satuan)")
plt.legend()
plt.grid(True)
plt.show()

# Plot data tambahan
plt.plot(data_graph["tahun"], data_graph["laba"], color="blue", marker="o", label="Laba")
plt.plot(data_graph["tahun"], data_graph["penjualan"], color="green", marker="o", label="Penjualan")
plt.plot(data_graph["tahun"], data_graph["pajak"], color="red", marker="x", label="Pajak")
plt.plot(data_graph["tahun"], data_graph["operasional"], color="orange", marker="x", label="Operasional")
plt.plot(data_graph["tahun"], data_graph["pendapatan_lain"], color="purple", marker="x", label="Pendapatan Lain")

plt.title("Grafik Laba, Penjualan, Pajak, Pendapatan Lain, dan Operasional")
plt.xlabel("Tahun")
plt.ylabel("Nilai (dalam satuan)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# [{'nama': 'Iwan',
#   'nim': 2046363636,
#   'rangkuman_nilai': [{'Grade': ': B',
#                        'mata_kuliah': 'kecerdasan buatan',
#                        'nilai': '78.37 : 0 - 100'},
#                       {'Grade': ': B',
#                        'mata_kuliah': 'basis data 1',
#                        'nilai': '76.92 : 0 - 100'},
#                       {'Grade': ': B',
#                        'mata_kuliah': 'digital enterpreneur',
#                        'nilai': '84.6 : 0 - 100'}]},
#  {'nama': 'Saepulloh',
#   'nim': 2046363777,
#   'rangkuman_nilai': [{'Grade': ': B',
#                        'mata_kuliah': 'algoritma & pemrogaman 1',
#                        'nilai': '79.52 : 0 - 100'},
#                       {'Grade': ': C',
#                        'mata_kuliah': 'kalkulus 1',
#                        'nilai': '68.8 : 0 - 100'},
#                       {'Grade': ': B',
#                        'mata_kuliah': 'statistika dan probabilitas',
# ...
